# %% [markdown]
# <a href="https://colab.research.google.com/github/hojuly/study_RecSys/blob/master/example_tfidf_recsys_movielens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # example_tfidf_recsys_movielens

# %% [markdown]
# ## Preprocess

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
import io
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-012e59fb-3cd2-4cd2-852e-069633c7b30e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-012e59fb-3cd2-4cd2-852e-069633c7b30e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movies.csv to movies (1).csv
# Saving ratings.csv to ratings (1).csv
# Saving tags.csv to tags (1).csv

# %%
ratings_df = pd.read_csv(io.StringIO(uploaded['ratings.csv'].decode('utf-8')))
movies_df = pd.read_csv(io.StringIO(uploaded['movies.csv'].decode('utf-8')), index_col=0)
tags_df = pd.read_csv(io.StringIO(uploaded['tags.csv'].decode('utf-8')))

# %%
total_count = len(movies_df.index)
total_genres = list(
    set([genre for sublist in list(map(lambda x: x.split('|'), movies_df['genres'])) for genre in sublist])
)

# %%
print(f"전체 영화 수: {total_count}")
print(f"장르: {total_genres}")
# Out:
# 전체 영화 수: 9742
# 장르: ['War', 'Action', 'Thriller', 'Sci-Fi', 'Film-Noir', 'Comedy', 'Mystery', 'Animation', 'Children', 'Fantasy', '(no genres listed)', 'Adventure', 'Crime', 'IMAX', 'Drama', 'Musical', 'Documentary', 'Horror', 'Western', 'Romance']

# %% [markdown]
# ## GENRES 이용

# %%
genre_count = dict.fromkeys(total_genres)

for each_genre_list in movies_df['genres']:
    for genre in each_genre_list.split('|'):
        if genre_count[genre] == None:
            genre_count[genre] = 1
        else:
            genre_count[genre] = genre_count[genre]+1

# %%
genre_count
# Out:
# {'(no genres listed)': 34,
#  'Action': 1828,
#  'Adventure': 1263,
#  'Animation': 611,
#  'Children': 664,
#  'Comedy': 3756,
#  'Crime': 1199,
#  'Documentary': 440,
#  'Drama': 4361,
#  'Fantasy': 779,
#  'Film-Noir': 87,
#  'Horror': 978,
#  'IMAX': 158,
#  'Musical': 334,
#  'Mystery': 573,
#  'Romance': 1596,
#  'Sci-Fi': 980,
#  'Thriller': 1894,
#  'War': 382,
#  'Western': 167}

# %%
for each_genre in genre_count:
    genre_count[each_genre] = np.log10(total_count/genre_count[each_genre])
  
genre_count
# Out:
# {'(no genres listed)': 2.457169208193496,
#  'Action': 0.7266719338379385,
#  'Adventure': 0.8872447746804204,
#  'Animation': 1.2026069149931968,
#  'Children': 1.1664800458677336,
#  'Comedy': 0.41392254164167785,
#  'Crime': 0.9098289421369025,
#  'Documentary': 1.3451954487495636,
#  'Drama': 0.3490620385623247,
#  'Fantasy': 1.0971106675631868,
#  'Film-Noir': 2.0491288726171324,
#  'Horror': 0.9983092704481497,
#  'IMAX': 1.7899910382813284,
#  'Musical': 1.4649016584241867,
#  'Mystery': 1.2304935032683613,
#  'Romance': 0.7856152382210405,
#  'Sci-Fi': 0.9974220495432562,
#  'Thriller': 0.7112681505684965,
#  'War': 1.4065847623240424,
#  'Western': 1.7659316540881678}

# %%
# create genre representations
genre_representation = pd.DataFrame(columns=sorted(total_genres), index=movies_df.index)
for index, each_row in tqdm(movies_df.iterrows()):
    dict_temp = {i: genre_count[i] for i in each_row['genres'].split('|')}
    row_to_add = pd.DataFrame(dict_temp, index=[index])
    genre_representation.update(row_to_add)

genre_representation.head()
# Out:
# 9742it [01:05, 149.16it/s]
#         (no genres listed) Action Adventure  ... Thriller  War Western
# movieId                                      ...
# 1                      NaN    NaN  0.887245  ...      NaN  NaN     NaN
# 2                      NaN    NaN  0.887245  ...      NaN  NaN     NaN
# 3                      NaN    NaN       NaN  ...      NaN  NaN     NaN
# 4                      NaN    NaN       NaN  ...      NaN  NaN     NaN
# 5                      NaN    NaN       NaN  ...      NaN  NaN     NaN
#
# [5 rows x 20 columns]

# %% [markdown]
# ## TAGS 이용

# %%
tags_df.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies_df.loc[89774]
# Out:
# title     Warrior (2011)
# genres             Drama
# Name: 89774, dtype: object

# %%
# get unique tag
tag_column = list(map(lambda x: x.split(','), tags_df['tag']))
unique_tags = list(set(list(map(lambda x: x.strip(), list([tag for sublist in tag_column for tag in sublist])))))

print(unique_tags)
# Out:
# ['Crude humor', 'cartoon', 'mindless one liners', 'violence', 'Leonardo DiCaprio', 'irreverent', 'adult humor', 'Insurance', 'pregnancy', 'General Motors', 'the catholic church is the most corrupt organization in history', 'prequel', 'ironic', 'will ferrell', 'imdb top 250', 'Strangers on a Train', 'heroic bloodshed', 'cult', 'bad', 'cynical', 'Venice', 'animal movie', 'autism', 'entirely dialogue', 'Trey Parker', '2001-like', 'Aardman', 'Ghost', 'lawyers', 'not linear', 'Ben Kingsley', 'Chris Evans', 'Teen movie', 'Louisa May Alcott', 'Henry James', 'bromantic', 'Oscar (Best Supporting Actress)', 'GIVE ME BACK MY SON!', 'allegorical', 'Keanu Reeves', 'economics', 'Shakespeare', 'EPIC', 'NASA', 'dreamy', 'stop using useless characters for filler', 'ark of the covenant', 'nostalgia', 'court', 'doctors', 'Vietnam', 'Hepburn and Tracy', 'Lloyd Dobbler', 'Jude Law', 'a clever chef rat', 'lyrical', 'plastic surgery', 'Jessica Alba', 'organized crime', 'hip hop', 'meditative', 'non-linear', 'violent', 'solitude', 'anime', 'Stephen Crane', 'chess', 'monologue', 'rich guy - poor girl', 'Christmas', 'Amtrak', 'Heroic Bloodshed', 'procedural', 'chilly', 'fish', 'class', 'Adrien Brody', 'aviation', 'bad dialogue', 'fast-paced', 'mental illness', 'twisted', 'police', 'Mozart', 'In Netflix queue', 'beautiful', '"artsy"', 'organised crime', 'hallucinatory', 'divorce', 'Robert Ludlum', 'earnest', 'Housekeeper', 'Stock Market', 'Saturday Night Live', 'war', 'homeless', 'submarine', 'evil children', 'bombs', 'casual violence', 'orphans', 'romance', 'Everything you want is here', 'Andy Samberg', 'scenic', 'Jason Biggs', 'heartbreaking', 'magic board game', 'Jason', 'weather forecaster', 'updated classics', 'new society', 'great cinematography', 'Ghosts', 'colourful', 'beat poetry', 'unconventional', 'r:graphic sexuality', 'marijuana', 'American Indians', 'race', 'murder', 'stapler', 'Alicia Vikander', 'Jared Leto', 'British gangster', 'trains', 'non-linear timeline', 'double life', 'heroine in tight suit', 'remix culture', 'killer-as-protagonist', 'nocturnal', 'Up series', 'DC Comics', 'poor dialogue', 'fairy tale', 'mind-bending', 'KIDNAPPING', 'Kevin Spacey', 'Samuel L. Jackson', 'stylish', 'Michael Crichton', 'Adventure', 'planes', 'alone in the world', 'grim', 'pageant', 'figure skating', 'gritty', 'pizza beer', 'Mexico', 'joss whedon', 'paranoia', 'bizarre', 'tear jerker', 'great acting', 'tobacco', 'cheesy', 'stiller', 'Cambodia', 'quirky romantic', 'spiders', 'postmodern', 'good music', 'multiple short stories', 'John Travolta', 'Borg', 'Juliette Lewis', 'britpop', 'Rachel Weisz', 'innovative', 'societal criticism', 'Great performances', 'claustrophobic', 'teenagers', 'Hilary Swank', 'futuristic', 'Turkey', 'true story', 'Mental Hospital', 'fighting', 'thriller', 'circus', 'James Franco', 'brainwashing', 'apes', 'Gulf War', 'Hungary', 'Capone', 'video games', 'geeky', 'biking', 'fast paced', 'fun family movie', 'leonardo DiCarpio', 'small time criminals', 'McCarthy hearings', 'black hole', 'French', 'Anne Hathaway', 'future', 'visually stunning', 'creativity', 'witty', 'alcoholism', 'cool', 'books', 'slow action', 'realistic', 'cheeky', 'Kevin Smith', 'boxing', 'bible', 'political commentary', 'spoof', 'r:strong bloody violence', 'satirical', 'pixar', 'David Thewlis', 'Mystery', 'stephen king', 'dc comics', 'spies', '1900s', 'fatherhood', 'tricky', 'meryl streep', 'aardman', 'Post apocalyptic', 'Politics', 'Cold', 'big name actors', 'visual', 'beautiful visuals', 'George Clooney', 'father-son relationship', 'Edith Wharton', 'episodic', 'Toto', 'alan rickman', 'movie business', 'longing', 'vertriloquism', 'surfing', 'Las Vegas', 'a dingo ate my baby', 'magic', 'good', 'families', 'gold', 'Wall Street', 'falling', 'video game adaptation', 'Brittany Murphy', 'offensive', 'stylized', 'opera', 'Will Smith', 'ben stiller', 'dinosaurs', 'Soundtrack', 'Train', 'aggressive', 'cruel characters', 'martial arts', 'big budget', 'really bad', 'Taranti ...

# %%
print(len(tag_column))
print(len(unique_tags))
# Out:
# 3683
# 1589

# %%
# Compute IDF for tag
total_movie_count = len(set(tags_df['movieId']))
# key: tag, value: number of movies with such tag
tag_count_dict = dict.fromkeys(unique_tags)

for each_movie_tag_list in tags_df['tag']:
    for tag in each_movie_tag_list.split(","):
        if tag_count_dict[tag.strip()] == None:
            tag_count_dict[tag.strip()] = 1
        else:
            tag_count_dict[tag.strip()] += 1

tag_idf = dict()
for each_tag in tag_count_dict:
    tag_idf[each_tag] = np.log10(total_movie_count / tag_count_dict[each_tag])

tag_idf

# %%
len(tag_idf.keys())
# Out:
# 1589

# %%
# Create movie representations
tag_representation = pd.DataFrame(columns=sorted(unique_tags), index=list(set(tags_df['movieId'])))
for name, group in tqdm(tags_df.groupby(by='movieId')):
    temp_list = list(map(lambda x: x.split(','), list(group['tag'])))
    temp_tag_list = list(set(list(map(lambda x: x.strip(), list([tag for sublist in temp_list for tag in sublist])))))

    dict_temp = {i: tag_idf[i.strip()] for i in temp_tag_list}
    row_to_add = pd.DataFrame(dict_temp, index=[group['movieId'].values[0]])
    tag_representation.update(row_to_add)

tag_representation = tag_representation.sort_index(0)
tag_representation.head()
# Out:
# 100%|██████████| 1572/1572 [05:06<00:00,  5.12it/s]
#   "artsy" 06 Oscar Nominated Best Movie - Animation  ... zoe kazan zombies
# 1     NaN                                       NaN  ...       NaN     NaN
# 2     NaN                                       NaN  ...       NaN     NaN
# 3     NaN                                       NaN  ...       NaN     NaN
# 5     NaN                                       NaN  ...       NaN     NaN
# 7     NaN                                       NaN  ...       NaN     NaN
#
# [5 rows x 1589 columns]

# %%
movies_df.head()
# Out:
#                                       title                                       genres
# movieId
# 1                          Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2                            Jumanji (1995)                   Adventure|Children|Fantasy
# 3                   Grumpier Old Men (1995)                               Comedy|Romance
# 4                  Waiting to Exhale (1995)                         Comedy|Drama|Romance
# 5        Father of the Bride Part II (1995)                                       Comedy

# %%
tag_representation.loc[1].dropna()
# Out:
# fun      2.49748
# pixar    2.89542
# Name: 1, dtype: object

# %%
tag_representation.loc[2].dropna()
# Out:
# Robin Williams      2.71933
# fantasy              2.4183
# game                3.19645
# magic board game    3.19645
# Name: 2, dtype: object

# %%
print(genre_representation.shape)
print(tag_representation.shape)
# Out:
# (9742, 20)
# (1572, 1589)

# %%
movie_representation = pd.concat([genre_representation, tag_representation], axis=1).fillna(0)
print(movie_representation.shape)
movie_representation.describe()
# Out:
# (9742, 1609)
#        (no genres listed)       Action  ...    zoe kazan      zombies
# count         9742.000000  9742.000000  ...  9742.000000  9742.000000
# mean             0.008576     0.136354  ...     0.000328     0.001241
# std              0.144915     0.283726  ...     0.032385     0.054775
# min              0.000000     0.000000  ...     0.000000     0.000000
# 25%              0.000000     0.000000  ...     0.000000     0.000000
# 50%              0.000000     0.000000  ...     0.000000     0.000000
# 75%              0.000000     0.000000  ...     0.000000     0.000000
# max              2.457169     0.726672  ...     3.196453     2.418301
#
# [8 rows x 1609 columns]

# %% [markdown]
# ## Contents 유사도 평가

# %%
from sklearn.metrics.pairwise import cosine_similarity


def cos_sim_matrix(a, b):
    cos_sim = cosine_similarity(a, b)
    result_df = pd.DataFrame(data=cos_sim, index=[a.index])
    return result_df

# %%
movie_representation.head()
# Out:
#    (no genres listed)  Action  Adventure  ...  zither  zoe kazan  zombies
# 1                 0.0     0.0   0.887245  ...     0.0        0.0      0.0
# 2                 0.0     0.0   0.887245  ...     0.0        0.0      0.0
# 3                 0.0     0.0   0.000000  ...     0.0        0.0      0.0
# 4                 0.0     0.0   0.000000  ...     0.0        0.0      0.0
# 5                 0.0     0.0   0.000000  ...     0.0        0.0      0.0
#
# [5 rows x 1609 columns]

# %%
cs_df = cos_sim_matrix(movie_representation, movie_representation)
cs_df.head()
# Out:
#        0         1         2     ...      9739      9740      9741
# 1  1.000000  0.124438  0.008403  ...  0.000000  0.232553  0.093519
# 2  0.124438  1.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3  0.008403  0.000000  1.000000  ...  0.000000  0.000000  0.089849
# 4  0.040571  0.000000  0.179391  ...  0.365843  0.000000  0.433821
# 5  0.011755  0.000000  0.011294  ...  0.000000  0.000000  0.125697
#
# [5 rows x 9742 columns]

# %%
cs_df.shape
# Out:
# (9742, 9742)

# %%
print(cs_df.shape)
cs_df[1].sort_values(ascending=False)
# Out:
# (9742, 9742)
# 2         1.000000
# 46972     0.322201
# 126142    0.300850
# 2043      0.300850
# 2399      0.300850
#             ...
# 39449     0.000000
# 39516     0.000000
# 39715     0.000000
# 39869     0.000000
# 7299      0.000000
# Name: 1, Length: 9742, dtype: float64

# %%
print(movies_df.loc[1])
print(movies_df.loc[46972])
print(movies_df.loc[126142])
print(movies_df.loc[2043])
print(movies_df.loc[2399])
# Out:
# title                                Toy Story (1995)
# genres    Adventure|Animation|Children|Comedy|Fantasy
# Name: 1, dtype: object
# title     Night at the Museum (2006)
# genres    Action|Comedy|Fantasy|IMAX
# Name: 46972, dtype: object
# title     The Cave of the Golden Rose (1991)
# genres            Adventure|Children|Fantasy
# Name: 126142, dtype: object
# title     Darby O'Gill and the Little People (1959)
# genres                   Adventure|Children|Fantasy
# Name: 2043, dtype: object
# title     Santa Claus: The Movie (1985)
# genres       Adventure|Children|Fantasy
# Name: 2399, dtype: object

# %% [markdown]
# ## 성능 평가

# %%
train_df, test_df = train_test_split(
    ratings_df,
    test_size=0.2,
    random_state=1234
)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (80668, 4)
# (20168, 4)

# %%
test_userids = list(set(test_df.userId.values))
test_userids

# %%
result_df = pd.DataFrame()

for user_id in tqdm(test_userids):
    user_record_df = train_df.loc[train_df.userId == int(user_id), :]
    
    user_sim_df = cs_df.loc[user_record_df['movieId']]  # (n, 9742); n은 userId가 평점을 매긴 영화 수
    user_rating_df = user_record_df[['rating']]  # (n, 1)
    sim_sum = np.sum(user_sim_df.T.to_numpy(), -1)  # (9742, 1)
    # print("user_id=", i, user_record_df.shape, user_sim_df.T.shape, user_rating_df.shape, sim_sum.shape)

    prediction = np.matmul(user_sim_df.T.to_numpy(), user_rating_df.to_numpy()).flatten() / (sim_sum+1) # (9742, 1)

    prediction_df = pd.DataFrame(prediction, index=cs_df.index).reset_index()
    prediction_df.columns = ['movieId', 'pred_rating']    
    prediction_df = prediction_df[['movieId', 'pred_rating']][prediction_df.movieId.isin(test_df[test_df.userId == user_id]['movieId'].values)]

    temp_df = prediction_df.merge(test_df[test_df.userId == user_id], on='movieId')
    result_df = pd.concat([result_df, temp_df], axis=0)
# Out:
# 100%|██████████| 610/610 [00:21<00:00, 28.24it/s]

# %%
result_df.head(10)
# Out:
#    movieId  pred_rating  userId  rating  timestamp
# 0        1     4.145652       1     4.0  964982703
# 1       50     3.650755       1     5.0  964982931
# 2      216     2.670124       1     5.0  964981208
# 3      223     2.612844       1     3.0  964980985
# 4      231     4.215284       1     5.0  964981179
# 5      235     3.619820       1     4.0  964980908
# 6      316     4.136756       1     3.0  964982310
# 7      457     3.218743       1     5.0  964981909
# 8      543     3.729524       1     4.0  964981179
# 9      592     4.024728       1     4.0  964982271

# %%
mse = mean_squared_error(y_true=result_df['rating'].values, y_pred=result_df['pred_rating'].values)
rmse = np.sqrt(mse)

print(mse, rmse)
# Out:
# 1.40606646706041 1.1857767357561078
